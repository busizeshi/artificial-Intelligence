# %%
import numpy as np

# %%
array1=np.array([[1,2,3],[4,5,6]])
np.sum(array1)
# Out:
# np.int64(21)

# %%
np.sum(array1,axis=0)
# Out:
# array([5, 7, 9])

# %%
array1.ndim
# Out:
# 2

# %%
np.prod(array1)
# Out:
# np.int64(720)

# %%
array1.prod(axis=0)
# Out:
# array([ 4, 10, 18])

# %%
array1.prod(axis=-1)
# Out:
# array([  6, 120])

# %%
array1.min()
# Out:
# np.int64(1)

# %%
array1.min(axis=1)
# Out:
# array([1, 4])

# %%
array1.max()
# Out:
# np.int64(6)

# %%
array1.argmin()
# Out:
# np.int64(0)

# %%
array1.argmin(axis=1)
# Out:
# array([0, 0])

# %%
array1.argmax(axis=1)
# Out:
# array([2, 2])

# %%
array1.mean()
# Out:
# np.float64(3.5)

# %%
array1.mean(axis=1)
# Out:
# array([2., 5.])

# %%
array1.std()
# Out:
# np.float64(1.707825127659933)

# %%
array1.var()
# Out:
# np.float64(2.9166666666666665)

# %%
array1.clip(2,3)
# Out:
# array([[2, 2, 3],
#        [3, 3, 3]])

# %%
array2=np.array([1.2,2.4,3.6])
np.around(array2)
# Out:
# array([1., 2., 4.])

# %%
array2.round(decimals=1)
# Out:
# array([1.2, 2.4, 3.6])
