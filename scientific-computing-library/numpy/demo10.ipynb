# %% [markdown]
# 读写文件

# %%
import numpy as np

# %%
# %%writefile jwd.txt
# 1 2 3 4 5 6
# 2 3 4 5 6 7
# Out:
# Writing jwd.txt

# %%
data=np.loadtxt("jwd.txt")

# %%
data
# Out:
# array([[1., 2., 3., 4., 5., 6.],
#        [2., 3., 4., 5., 6., 7.]])

# %%
# %%writefile jwd.txt
# 1,2,3,4,5,6
# 2,3,4,5,6,7
# Out:
# Overwriting jwd.txt

# %%
data=np.loadtxt("jwd.txt",delimiter=",")

# %%
data
# Out:
# array([[1., 2., 3., 4., 5., 6.],
#        [2., 3., 4., 5., 6., 7.]])

# %%
# %%writefile jwd.txt
# x,y, z, a, b
# 1,2,3,4,5
# 2,3,4,5,6
# Out:
# Overwriting jwd.txt

# %%
data=np.loadtxt("jwd.txt",delimiter=",",skiprows=1)
data
# Out:
# array([[1., 2., 3., 4., 5.],
#        [2., 3., 4., 5., 6.]])
